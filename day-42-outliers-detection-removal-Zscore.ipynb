# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mergedCarea.csv')

# %%
df.shape
# Out:
# (376, 2154)

# %%
df[df['Carea']<0]
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 190         190  BNL12621  24.67  24.41  24.07  23.61  23.05  22.43  21.80
# 191         191  BNL12622  25.60  25.47  25.34  25.05  24.56  24.03  23.42
#
#        357  ...  2492  2493  2494  2495  2496  2497  2498  2499  2500   Carea
# 190  21.28  ...  2.52  2.53  2.50  2.44  2.46  2.47  2.44  2.45  2.37 -9999.0
# 191  22.77  ...  2.81  2.86  2.82  2.74  2.72  2.63  2.55  2.58  2.54 -9999.0
#
# [2 rows x 2154 columns]

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 38           38  BNL12812   3.59   3.54   3.43   3.46   3.64   3.67   3.91
# 174         174  BNL12605  25.16  25.10  24.84  24.43  23.93  23.35  22.70
# 258         258  BNL12760  26.98  26.80  26.47  26.04  25.57  25.04  24.38
# 75           75  BNL12851   5.73   5.38   5.40   5.58   5.92   5.50   5.32
# 168         168  BNL12899   9.36   8.87   8.20   7.33   6.25   6.31   6.72
#
#        357  ...  2492  2493  2494  2495  2496  2497  2498  2499  2500   Carea
# 38    4.27  ...  5.54  5.53  5.48  5.42  5.42  5.43  5.44  5.43  5.43   50.63
# 174  22.01  ...  2.89  2.87  2.80  2.72  2.74  2.76  2.75  2.80  2.76  142.19
# 258  23.57  ...  3.88  3.88  3.80  3.68  3.65  3.56  3.47  3.50  3.46   66.85
# 75    5.24  ...  4.24  4.22  4.19  4.17  4.17  4.19  4.19  4.18  4.16  116.48
# 168   7.22  ...  2.77  2.76  2.75  2.76  2.79  2.83  2.84  2.83  2.81   57.98
#
# [5 rows x 2154 columns]

# %%
df = df.drop(df[df['Carea']<0].index)
df.shape
# Out:
# (374, 2154)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Carea'])

plt.subplot(1,2,2)
sns.distplot(df['350'])

plt.show()
# Out:
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_11284\1790986807.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Carea'])
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_11284\1790986807.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['350'])

# %%
df['Carea'].skew()
# Out:
# 1.936468494751957

# %%
print("Mean value of Carea",df['Carea'].mean())
print("Std value of Carea",df['Carea'].std())
print("Min value of Carea",df['Carea'].min())
print("Max value of Carea",df['Carea'].max())
# Out:
# Mean value of Carea 50.65385026737968
# Std value of Carea 24.79607875985473
# Min value of Carea 15.46
# Max value of Carea 168.9

# %%
# Finding the boundary values

print("Highest allowed ",df['Carea'].mean() + 3*df['Carea'].std())
print("Lowest allowed ",df['Carea'].mean() - 3*df['Carea'].std())
# Out:
# Highest allowed  125.04208654694386
# Lowest allowed  -23.7343860121845

# %%
# Finding the outliers
df[(df['Carea'] >125.04208654694386) | (df['Carea']< -23.7343860121845)]
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 159         159  BNL12890   1.76   1.35   2.34   2.86   2.91   2.20   2.21
# 160         160  BNL12891   5.66   4.94   5.09   4.97   4.58   4.50   4.50
# 171         171  BNL12602  34.86  34.59  34.01  33.30  32.56  31.68  30.69
# 172         172  BNL12603  30.87  30.63  30.29  29.78  29.09  28.27  27.38
# 173         173  BNL12604  27.50  27.33  26.93  26.40  25.84  25.22  24.52
# 174         174  BNL12605  25.16  25.10  24.84  24.43  23.93  23.35  22.70
# 335         335  BNL12905  20.77  20.93  21.04  20.95  20.66  20.27  19.73
# 336         336  BNL12906  24.31  24.24  24.15  23.95  23.62  23.19  22.64
# 337         337  BNL12907  23.15  23.06  22.90  22.57  22.05  21.49  20.85
# 338         338  BNL12908  22.75  22.71  22.58  22.31  21.94  21.48  20.91
# 339         339  BNL12909  19.64  19.60  19.47  19.24  18.92  18.50  17.96
# ...

# %% [markdown]
# ## Trimming

# %%
# Trimming

new_df = df[(df['Carea'] < 125.04208654694386) & (df['Carea']> -23.7343860121845)]
new_df
# Out:
#      Unnamed: 0 Sample_ID   350   351   352   353   354   355   356   357  \
# 0             0  BNL12801  4.80  4.44  4.88  4.99  4.79  4.67  4.53  4.38
# 1             1  BNL12802  3.93  3.97  3.40  2.94  2.59  3.29  3.40  3.14
# 2             2  BNL12803  6.11  6.17  6.11  5.63  4.72  4.57  4.05  3.35
# 3             3  BNL12804  4.87  4.27  3.60  3.60  4.27  4.22  4.24  4.33
# 4             4  BNL12805  3.53  3.46  3.83  4.32  4.91  5.22  4.88  4.10
# ..          ...       ...   ...   ...   ...   ...   ...   ...   ...   ...
# 371         371       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 372         372       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 373         373       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 374         374       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 375         375       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...  2492  2493  2494  2495  2496  2497  2498  2499  2500  Carea
# ...

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0     0
# Sample_ID     19
# 350           19
# 351           19
# 352           19
#               ..
# 2497          19
# 2498          19
# 2499          19
# 2500          19
# Carea          0
# Length: 2154, dtype: int64

# %%
# Approach 2

# Calculating the Zscore
df['Carea_zscore'] = (df['Carea'] - df['Carea'].mean())/ df['Carea'].std()

# %%
df.head()
# Out:
#    Unnamed: 0 Sample_ID   350   351   352   353   354   355   356   357  ...  \
# 0           0  BNL12801  4.80  4.44  4.88  4.99  4.79  4.67  4.53  4.38  ...
# 1           1  BNL12802  3.93  3.97  3.40  2.94  2.59  3.29  3.40  3.14  ...
# 2           2  BNL12803  6.11  6.17  6.11  5.63  4.72  4.57  4.05  3.35  ...
# 3           3  BNL12804  4.87  4.27  3.60  3.60  4.27  4.22  4.24  4.33  ...
# 4           4  BNL12805  3.53  3.46  3.83  4.32  4.91  5.22  4.88  4.10  ...
#
#    2493  2494  2495  2496  2497  2498  2499  2500  Carea  Carea_zscore
# 0  9.84  9.77  9.69  9.70  9.74  9.75  9.74  9.70  80.90      1.219796
# 1  3.35  3.33  3.32  3.33  3.35  3.37  3.39  3.39  88.73      1.535571
# 2  2.84  2.84  2.83  2.82  2.82  2.82  2.83  2.83  88.73      1.535571
# 3  4.91  4.87  4.82  4.80  4.80  4.80  4.81  4.80  65.94      0.616474
# 4  4.31  4.29  4.26  4.26  4.28  4.28  4.28  4.27  65.94      0.616474
#
# [5 rows x 2155 columns]

# %%
df[df['Carea_zscore']>3]
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 159         159  BNL12890   1.76   1.35   2.34   2.86   2.91   2.20   2.21
# 160         160  BNL12891   5.66   4.94   5.09   4.97   4.58   4.50   4.50
# 171         171  BNL12602  34.86  34.59  34.01  33.30  32.56  31.68  30.69
# 172         172  BNL12603  30.87  30.63  30.29  29.78  29.09  28.27  27.38
# 173         173  BNL12604  27.50  27.33  26.93  26.40  25.84  25.22  24.52
# 174         174  BNL12605  25.16  25.10  24.84  24.43  23.93  23.35  22.70
# 335         335  BNL12905  20.77  20.93  21.04  20.95  20.66  20.27  19.73
# 336         336  BNL12906  24.31  24.24  24.15  23.95  23.62  23.19  22.64
# 337         337  BNL12907  23.15  23.06  22.90  22.57  22.05  21.49  20.85
# 338         338  BNL12908  22.75  22.71  22.58  22.31  21.94  21.48  20.91
# 339         339  BNL12909  19.64  19.60  19.47  19.24  18.92  18.50  17.96
# ...

# %%
df[df['Carea_zscore']<-3]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Sample_ID, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, ...]
# Index: []
#
# [0 rows x 2155 columns]

# %%
df[(df['Carea_zscore']>3) | (df['Carea_zscore'] < -3)]
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 159         159  BNL12890   1.76   1.35   2.34   2.86   2.91   2.20   2.21
# 160         160  BNL12891   5.66   4.94   5.09   4.97   4.58   4.50   4.50
# 171         171  BNL12602  34.86  34.59  34.01  33.30  32.56  31.68  30.69
# 172         172  BNL12603  30.87  30.63  30.29  29.78  29.09  28.27  27.38
# 173         173  BNL12604  27.50  27.33  26.93  26.40  25.84  25.22  24.52
# 174         174  BNL12605  25.16  25.10  24.84  24.43  23.93  23.35  22.70
# 335         335  BNL12905  20.77  20.93  21.04  20.95  20.66  20.27  19.73
# 336         336  BNL12906  24.31  24.24  24.15  23.95  23.62  23.19  22.64
# 337         337  BNL12907  23.15  23.06  22.90  22.57  22.05  21.49  20.85
# 338         338  BNL12908  22.75  22.71  22.58  22.31  21.94  21.48  20.91
# 339         339  BNL12909  19.64  19.60  19.47  19.24  18.92  18.50  17.96
# ...

# %%
# Trimming 
new_df = df[(df['Carea_zscore']<3) | (df['Carea_zscore'] > -3)]

# %%
new_df
# Out:
#      Unnamed: 0 Sample_ID   350   351   352   353   354   355   356   357  \
# 0             0  BNL12801  4.80  4.44  4.88  4.99  4.79  4.67  4.53  4.38
# 1             1  BNL12802  3.93  3.97  3.40  2.94  2.59  3.29  3.40  3.14
# 2             2  BNL12803  6.11  6.17  6.11  5.63  4.72  4.57  4.05  3.35
# 3             3  BNL12804  4.87  4.27  3.60  3.60  4.27  4.22  4.24  4.33
# 4             4  BNL12805  3.53  3.46  3.83  4.32  4.91  5.22  4.88  4.10
# ..          ...       ...   ...   ...   ...   ...   ...   ...   ...   ...
# 371         371       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 372         372       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 373         373       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 374         374       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 375         375       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...  2493  2494  2495  2496  2497  2498  2499  2500  Carea  Carea_zscore
# ...

# %% [markdown]
# ## Capping

# %%
upper_limit = df['Carea'].mean() + 3*df['Carea'].std()
lower_limit = df['Carea'].mean() - 3*df['Carea'].std()

# %%
lower_limit
# Out:
# -23.7343860121845

# %%
df['Carea'] = np.where(
    df['Carea'] > upper_limit,
    upper_limit,
    np.where(df['Carea'] < lower_limit,
            lower_limit,
             df['Carea']
            )
)

# %%
df.shape
# Out:
# (374, 2155)

# %%
df['Carea'].describe()
# Out:
# count    374.000000
# mean      50.085254
# std       22.676587
# min       15.460000
# 25%       35.260000
# 50%       44.490000
# 75%       58.250000
# max      125.042087
# Name: Carea, dtype: float64
