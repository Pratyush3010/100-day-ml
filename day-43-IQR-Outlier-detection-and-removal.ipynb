# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mergedCarea.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Sample_ID   350   351   352   353   354   355   356   357  ...  \
# 0           0  BNL12801  4.80  4.44  4.88  4.99  4.79  4.67  4.53  4.38  ...
# 1           1  BNL12802  3.93  3.97  3.40  2.94  2.59  3.29  3.40  3.14  ...
# 2           2  BNL12803  6.11  6.17  6.11  5.63  4.72  4.57  4.05  3.35  ...
# 3           3  BNL12804  4.87  4.27  3.60  3.60  4.27  4.22  4.24  4.33  ...
# 4           4  BNL12805  3.53  3.46  3.83  4.32  4.91  5.22  4.88  4.10  ...
#
#    2492  2493  2494  2495  2496  2497  2498  2499  2500  Carea
# 0  9.88  9.84  9.77  9.69  9.70  9.74  9.75  9.74  9.70  80.90
# 1  3.37  3.35  3.33  3.32  3.33  3.35  3.37  3.39  3.39  88.73
# 2  2.83  2.84  2.84  2.83  2.82  2.82  2.82  2.83  2.83  88.73
# 3  4.92  4.91  4.87  4.82  4.80  4.80  4.80  4.81  4.80  65.94
# 4  4.31  4.31  4.29  4.26  4.26  4.28  4.28  4.28  4.27  65.94
#
# [5 rows x 2154 columns]

# %%
df = df.drop(df[df['Carea']<0].index)
df.shape
# Out:
# (374, 2154)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Carea'])

plt.subplot(1,2,2)
sns.distplot(df['350'])

plt.show()
# Out:
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\3222340711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Carea'])
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\3222340711.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['350'])

# %%
df['Carea'].describe()
# Out:
# count    374.000000
# mean      50.653850
# std       24.796079
# min       15.460000
# 25%       35.260000
# 50%       44.490000
# 75%       58.250000
# max      168.900000
# Name: Carea, dtype: float64

# %%
sns.boxplot (df['Carea'])
# Out:
# <Axes: ylabel='Carea'>

# %%
percentile25 = df['Carea'].quantile(0.25)
percentile75 = df['Carea'].quantile(0.75)

# %%
percentile75
# Out:
# 58.25

# %%
iqr = percentile75 - percentile25

# %%
iqr
# Out:
# 22.990000000000002

# %%
upper_limit = percentile75 + 1.5* iqr

# %%
lower_limit = percentile25 - 1.5 * iqr

# %%
print("Upper limit",upper_limit)
print('Lower limit',lower_limit)
# Out:
# Upper limit 92.735
# Lower limit 0.7749999999999986

# %% [markdown]
# ## Finding Outliers

# %%
df[df['Carea'] > upper_limit]
# Out:
#      Unnamed: 0 Sample_ID    350    351    352    353    354    355    356  \
# 75           75  BNL12851   5.73   5.38   5.40   5.58   5.92   5.50   5.32
# 76           76  BNL12852   5.74   6.32   6.26   6.20   6.12   5.46   5.04
# 82           82  BNL12858   6.32   6.57   6.39   6.07   5.61   5.33   4.72
# 83           83  BNL12859   6.14   5.80   4.72   4.28   4.48   5.66   6.28
# 159         159  BNL12890   1.76   1.35   2.34   2.86   2.91   2.20   2.21
# 160         160  BNL12891   5.66   4.94   5.09   4.97   4.58   4.50   4.50
# 171         171  BNL12602  34.86  34.59  34.01  33.30  32.56  31.68  30.69
# 172         172  BNL12603  30.87  30.63  30.29  29.78  29.09  28.27  27.38
# 173         173  BNL12604  27.50  27.33  26.93  26.40  25.84  25.22  24.52
# 174         174  BNL12605  25.16  25.10  24.84  24.43  23.93  23.35  22.70
# 181         181  BNL12612  25.19  24.99  24.90  24.70  24.30  23.75  23.06
# ...

# %%
df[df['Carea'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Sample_ID, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, ...]
# Index: []
#
# [0 rows x 2154 columns]

# %% [markdown]
# ## Trimming

# %%
new_df = df[df['Carea']<upper_limit]

# %%
new_df.shape
# Out:
# (355, 2154)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Carea'])

plt.subplot(2,2,2)
sns.boxplot(df['Carea'])

plt.subplot(2,2,3)
sns.distplot(new_df['Carea'])

plt.subplot(2,2,4)
sns.boxplot(new_df['Carea'])

plt.show()
# Out:
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\94883137.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Carea'])
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\94883137.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Carea'])

# %% [markdown]
# ## Capping

# %%
new_df_cap = df.copy()

new_df_cap['Carea'] = np.where(
    new_df_cap['Carea'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['Carea'] < lower_limit,
        lower_limit,
        new_df_cap['Carea']
    )
)

# %%
new_df_cap.shape
# Out:
# (374, 2154)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Carea'])

plt.subplot(2,2,2)
sns.boxplot(df['Carea'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['Carea'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['Carea'])

plt.show()
# Out:
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\3559446352.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Carea'])
# C:\Users\Pratyush\AppData\Local\Temp\ipykernel_8256\3559446352.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
