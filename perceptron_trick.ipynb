# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyush3010/100-day-ml/blob/master/perceptron_trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("100 days of DL")
# Out:
# 100 days of DL
